# %%
# 2. Grouped Mean
df.groupby('Department')['Salary'].mean()

# 5. Scatter Plot
import matplotlib.pyplot as plt
plt.scatter(df['Experience'], df['Salary'])

# 6. Bar Chart
sns.barplot(x='Department', y='Score', data=df)

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/employee_performance_dataset.csv")

# %%
df
# Out:
#     Employee_ID Department  Years_of_Experience  Monthly_Salary  \
# 0          2001         HR                    6           79835
# 1          2002         IT                    4           44123
# 2          2003         IT                    6           32640
# 3          2004         HR                    9           22926
# 4          2005    Finance                   12           55211
# 5          2006         IT                    3           76930
# 6          2007         IT                    6           67529
# 7          2008    Finance                   10           30228
# 8          2009  Marketing                    2           76912
# 9          2010    Finance                    1           34797
# 10         2011  Marketing                    1           74341
# 11         2012    Finance                    5           70149
# 12         2013  Marketing                    3           61403
# 13         2014         HR                   14           50043
# ...

# %%
df.head()
# Out:
#    Employee_ID Department  Years_of_Experience  Monthly_Salary  \
# 0         2001         HR                    6           79835
# 1         2002         IT                    4           44123
# 2         2003         IT                    6           32640
# 3         2004         HR                    9           22926
# 4         2005    Finance                   12           55211
#
#    Performance_Score
# 0                  2
# 1                  1
# 2                  6
# 3                  2
# 4                  7

# %%
df.tail()
# Out:
#     Employee_ID Department  Years_of_Experience  Monthly_Salary  \
# 15         2016    Finance                   10           38157
# 16         2017  Marketing                   14           54695
# 17         2018         HR                    1           46491
# 18         2019  Marketing                    9           67035
# 19         2020         HR                    7           62512
#
#     Performance_Score
# 15                  4
# 16                  7
# 17                  9
# 18                  3
# 19                  1

# %%
df.shape
# Out:
# (20, 5)

# %%
df.columns
# Out:
# Index(['Employee_ID', 'Department', 'Years_of_Experience', 'Monthly_Salary',
#        'Performance_Score'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Employee_ID          20 non-null     int64
#  1   Department           20 non-null     object
#  2   Years_of_Experience  20 non-null     int64
#  3   Monthly_Salary       20 non-null     int64
#  4   Performance_Score    20 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 932.0+ bytes

# %%
df.describe()
# Out:
#        Employee_ID  Years_of_Experience  Monthly_Salary  Performance_Score
# count     20.00000            20.000000       20.000000          20.000000
# mean    2010.50000             6.200000    55159.650000           5.200000
# std        5.91608             4.311551    17221.119877           2.894641
# min     2001.00000             1.000000    22926.000000           1.000000
# 25%     2005.75000             2.750000    42631.500000           2.750000
# 50%     2010.50000             6.000000    56223.500000           5.000000
# 75%     2015.25000             9.250000    68184.000000           7.000000
# max     2020.00000            14.000000    79835.000000          10.000000

# %%
df.isnull()
# Out:
#     Employee_ID  Department  Years_of_Experience  Monthly_Salary  \
# 0         False       False                False           False
# 1         False       False                False           False
# 2         False       False                False           False
# 3         False       False                False           False
# 4         False       False                False           False
# 5         False       False                False           False
# 6         False       False                False           False
# 7         False       False                False           False
# 8         False       False                False           False
# 9         False       False                False           False
# 10        False       False                False           False
# 11        False       False                False           False
# 12        False       False                False           False
# ...

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.sort_values("Years_of_Experience", ascending=False)
# Out:
#     Employee_ID Department  Years_of_Experience  Monthly_Salary  \
# 13         2014         HR                   14           50043
# 16         2017  Marketing                   14           54695
# 4          2005    Finance                   12           55211
# 7          2008    Finance                   10           30228
# 15         2016    Finance                   10           38157
# 18         2019  Marketing                    9           67035
# 3          2004         HR                    9           22926
# 19         2020         HR                    7           62512
# 0          2001         HR                    6           79835
# 2          2003         IT                    6           32640
# 6          2007         IT                    6           67529
# 11         2012    Finance                    5           70149
# 1          2002         IT                    4           44123
# 12         2013  Marketing                    3           61403
# ...

# %%
df.sort_values("Monthly_Salary", ascending=False)
# Out:
#     Employee_ID Department  Years_of_Experience  Monthly_Salary  \
# 0          2001         HR                    6           79835
# 5          2006         IT                    3           76930
# 8          2009  Marketing                    2           76912
# 10         2011  Marketing                    1           74341
# 11         2012    Finance                    5           70149
# 6          2007         IT                    6           67529
# 18         2019  Marketing                    9           67035
# 19         2020         HR                    7           62512
# 12         2013  Marketing                    3           61403
# 14         2015  Marketing                    1           57236
# 4          2005    Finance                   12           55211
# 16         2017  Marketing                   14           54695
# 13         2014         HR                   14           50043
# 17         2018         HR                    1           46491
# ...

# %%
df.sort_values("Performance_Score", ascending=False)
# Out:
#     Employee_ID Department  Years_of_Experience  Monthly_Salary  \
# 12         2013  Marketing                    3           61403
# 9          2010    Finance                    1           34797
# 17         2018         HR                    1           46491
# 6          2007         IT                    6           67529
# 13         2014         HR                   14           50043
# 16         2017  Marketing                   14           54695
# 10         2011  Marketing                    1           74341
# 4          2005    Finance                   12           55211
# 14         2015  Marketing                    1           57236
# 2          2003         IT                    6           32640
# 5          2006         IT                    3           76930
# 11         2012    Finance                    5           70149
# 15         2016    Finance                   10           38157
# 7          2008    Finance                   10           30228
# ...

# %%
# 1.Calculate the average salary
df['Monthly_Salary'].mean()
# Out:
# np.float64(55159.65)

# %%
import matplotlib.pyplot as plt

# %%
# 5.Create a Scatter Plot
plt.scatter(df["Years_of_Experience"], df["Monthly_Salary"])
plt.title("Experience vs. Salary")
plt.xlabel("Years of Experience")
plt.ylabel("Monthly Salary")
plt.grid(True)
plt.show()

# %%
# 6.Create a Bar Chart
plt.bar(df["Department"], df["Performance_Score"])
plt.title("Department vs. Average Performance Score")
plt.xlabel("Department")
plt.ylabel("Average Performance Score")
plt.xticks(rotation=90)
plt.show()

# %%
# Count the total number of High Performers in the company
df["Performance_Score"].sum()
# Out:
# np.int64(104)

# %%
# Count the total number of High Performers in the company
df[df["Performance_Score"] >= 7]
# Out:
#     Employee_ID Department  Years_of_Experience  Monthly_Salary  \
# 4          2005    Finance                   12           55211
# 6          2007         IT                    6           67529
# 9          2010    Finance                    1           34797
# 10         2011  Marketing                    1           74341
# 12         2013  Marketing                    3           61403
# 13         2014         HR                   14           50043
# 16         2017  Marketing                   14           54695
# 17         2018         HR                    1           46491
#
#     Performance_Score
# 4                   7
# 6                   8
# 9                  10
# 10                  7
# 12                 10
# 13                  7
# 16                  7
# 17                  9

# %%
# Count the total number of High Performers in the company
df[df["Performance_Score"] >= 7].count()
# Out:
# Employee_ID            8
# Department             8
# Years_of_Experience    8
# Monthly_Salary         8
# Performance_Score      8
# dtype: int64

# %%
# Create a new column called High_Performer
df["High_Performer"] = df["Performance_Score"] >= 7

# %%
df
# Out:
#     Employee_ID Department  Years_of_Experience  Monthly_Salary  \
# 0          2001         HR                    6           79835
# 1          2002         IT                    4           44123
# 2          2003         IT                    6           32640
# 3          2004         HR                    9           22926
# 4          2005    Finance                   12           55211
# 5          2006         IT                    3           76930
# 6          2007         IT                    6           67529
# 7          2008    Finance                   10           30228
# 8          2009  Marketing                    2           76912
# 9          2010    Finance                    1           34797
# 10         2011  Marketing                    1           74341
# 11         2012    Finance                    5           70149
# 12         2013  Marketing                    3           61403
# 13         2014         HR                   14           50043
# ...

# %%
# Calculate the average salary
df["Monthly_Salary"].mean()
# Out:
# np.float64(55159.65)

# %%
# Group employees by Department
df.groupby("Department")["Monthly_Salary"].mean()
# Out:
# Department
# Finance      45708.400000
# HR           52361.400000
# IT           55305.500000
# Marketing    65270.333333
# Name: Monthly_Salary, dtype: float64

# %%
# Group employees by Department
df[["Employee_ID","Department"]]
# Out:
#     Employee_ID Department
# 0          2001         HR
# 1          2002         IT
# 2          2003         IT
# 3          2004         HR
# 4          2005    Finance
# 5          2006         IT
# 6          2007         IT
# 7          2008    Finance
# 8          2009  Marketing
# 9          2010    Finance
# 10         2011  Marketing
# 11         2012    Finance
# 12         2013  Marketing
# 13         2014         HR
# 14         2015  Marketing
# 15         2016    Finance
# 16         2017  Marketing
# 17         2018         HR
# 18         2019  Marketing
# 19         2020         HR
